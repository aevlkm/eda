# %% [markdown]
# # Multi variete representation of continuous variables
#
# For this part, we will use the following dataset: *sales_predictions.csv*.

# %% [markdown]
# 1. Import usual librairies

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

import numpy as np

import seaborn as sns
sns.set_theme(style="whitegrid")

import matplotlib.pyplot as plt

from random import sample

# %%
df = pd.read_csv("src\sales_predictions.csv")
df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %% [markdown]
# 2. Use a _sample()_ to select 25 random entries from the dataset

# %%
df = df.sample(25)
df.head()
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2482696  22.02.2015              25       27     1916       249.0
# 201600   01.02.2013               1       38     4249      1899.0
# 856643   08.09.2013               8       21     8140       199.0
# 254336   24.03.2013               2       54    11833       100.0
# 261466   06.03.2013               2       54    18248       199.0
#
#          item_cnt_day
# 2482696           1.0
# 201600            1.0
# 856643            1.0
# 254336            1.0
# 261466            1.0

# %% [markdown]
# 3. Using _relplot(),_ build a chart that will allow you to see the price evolution over time. What can you see?

# %%
plt.subplots(figsize=(20, 5))
sns.lineplot(data= df, x= "date", y="item_price")
plt.show()

# %% [markdown]
# 4. Using the pd.to_datetime() function, convert your _date_ column to _datetime_.

# %%
df["date"] = pd.to_datetime(df["date"])
df["date"]
# Out:
# 2482696   2015-02-22
# 201600    2013-02-01
# 856643    2013-09-08
# 254336    2013-03-24
# 261466    2013-03-06
# 348317    2013-04-03
# 2034646   2014-10-23
# 2897967   2015-10-25
# 31334     2013-01-05
# 1446388   2014-02-08
# 1988847   2014-09-05
# 1244111   2013-12-17
# 555729    2013-06-09
# 96448     2013-01-09
# 1813562   2014-07-13
# 1410780   2014-02-03
# 2028857   2014-10-23
# 346292    2013-04-11
# 606169    2013-06-12
# 347875    2013-04-27
# 1373684   2014-02-03
# 20310     2013-01-08
# 646292    2013-07-10
# 1402802   2014-02-10
# 1154643   2013-12-08
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# 5. Retry doing your visualization. What do you see?

# %%
plt.subplots(figsize=(20, 5))
ax = sns.lineplot(data= df, x= "date", y="item_price")
# ax.set_xlim("2013-01-01", "2015-12-01")
plt.show()
