# %% [markdown]
# # Multi variete representation of continuous variables
#
# For this part, we will use the following dataset: *sales_predictions.csv*.

# %% [markdown]
# 1. Import usual librairies

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

import numpy as np

import seaborn as sns
sns.set_theme(style="whitegrid")

import matplotlib.pyplot as plt

from random import sample

# %%
df = pd.read_csv("src\sales_predictions.csv")
df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %% [markdown]
# 2. Use a _sample()_ to select 25 random entries from the dataset

# %%
df = df.sample(25)
df.head()
# Out:
#               date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 1056085 2013-11-22              10       31     9364       299.0           1.0
# 957184  2013-10-11               9       55     1831       599.0           2.0
# 2108910 2014-11-23              22       31    16180      1699.0           1.0
# 18776   2013-01-28               0       28     3120       399.0           1.0
# 2001256 2014-09-20              20       29       90       399.0           1.0

# %% [markdown]
# 3. Using _relplot(),_ build a chart that will allow you to see the price evolution over time. What can you see?

# %%
plt.figure(figsize=(20, 5))
sns.lineplot(data= df, x= "date", y="item_price")
plt.show()

# %% [markdown]
# 4. Using the pd.to_datetime() function, convert your _date_ column to _datetime_.

# %%
df["date"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 25 entries, 18776 to 1348475
# Series name: date
# Non-Null Count  Dtype
# --------------  -----
# 25 non-null     object
# dtypes: object(1)
# memory usage: 400.0+ bytes

# %%
df["date"] = pd.to_datetime(df["date"])
df["date"]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14488\2233123204.py:1: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["date"] = pd.to_datetime(df["date"])
# 18776     2013-01-28
# 921356    2013-09-27
# 2108910   2014-11-23
# 2073775   2014-10-11
# 1450789   2014-02-03
# 393829    2013-04-12
# 157819    2013-02-24
# 1396647   2014-02-28
# 1836751   2014-07-03
# 1781018   2014-06-21
# 592984    2013-06-07
# 2001256   2014-09-20
# 1111649   2013-11-11
# 2593914   2015-04-23
# 34722     2013-01-08
# 671632    2013-07-13
# 2635826   2015-05-05
# 871003    2013-09-25
# 2867367   2015-09-06
# 1753481   2014-06-01
# 776762    2013-08-15
# 2569223   2015-04-27
# 1056085   2013-11-22
# 957184    2013-10-11
# 1348475   2014-01-21
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# 5. Retry doing your visualization. What do you see?

# %%
plt.figure(figsize=(20, 5))
ax = sns.lineplot(data= df, x= "date", y="item_price")
plt.show()
